# %%
import pandas as pd
import numpy as np

# Transient state dataset.

df = pd.read_csv('./12_kw_to_O13__transient_data.csv')
df.head(5)
# Out:
#    Time  O13:Capacity Planning0 Temperature  \
# 0     0                           25.084000
# 1     1                           25.573700
# 2     2                           26.311800
# 3     3                           26.892500
# 4     4                           27.202101
#
#    O13:Capacity Planning1 Temperature  O13:Capacity Planning2 Temperature  \
# 0                           25.084000                           25.067600
# 1                           25.573700                           25.660801
# 2                           26.311800                           26.477100
# 3                           26.892500                           27.053900
# 4                           27.202101                           27.322001
#
#    O13:Capacity Planning3 Temperature  O13:Capacity Planning4 Temperature  \
# 0                           25.067600                           25.067600
# 1                           25.660801                           25.660801
# ...

# %%
# STEDY STATE

df2 = pd.read_csv('./12_kw_to_O13__steadystate_data.csv')
df2.head(5)
# Out:
#                Unnamed: 0  Max Temperature In  C
# 0  O13:Capacity Planning0                  25.08
# 1  O13:Capacity Planning1                  25.08
# 2  O13:Capacity Planning2                  25.07
# 3  O13:Capacity Planning3                  25.07
# 4  O13:Capacity Planning4                  25.07

# %%
# FAILURE

df3 = pd.read_csv('./12_kw_to_O13__failure_data.csv')
df3.head(5)
# Out:
#                Unnamed: 0  Max Temperature In  C
# 0  O13:Capacity Planning0                  25.14
# 1  O13:Capacity Planning1                  25.14
# 2  O13:Capacity Planning2                  25.10
# 3  O13:Capacity Planning3                  25.10
# 4  O13:Capacity Planning4                  25.10

# %%
# POWER

df4 = pd.read_csv('./12_kw_to_O13.csv')
df4
# Out:
#     Unnamed: 0 rack  power
# 0            0  O13     12
# 1            1  O14     10
# 2            2  O15     10
# 3            3  O17     10
# 4            4  O18     10
# 5            5  O19     10
# 6            6  O21     10
# 7            7  O22     10
# 8            8  R12     10
# 9            9  R13     10
# 10          10  R14     10
# 11          11  R16     10
# 12          12  R17     10
# 13          13  R18     10
# 14          14  R20     10
# 15          15  R21     10

# %%
# Scatter plot helper function
us = []
def grapher(frame,rack):
    plannings = ['7','14','21','28','35','42']
    color = ['DarkGreen','DarkRed','Yellow','Pink','Black','Red']
    label = ['_u7','_u14','_u21','_u28','_u35','_u42']
    u = frame.plot.scatter(x='Time', y=rack+':Capacity Planning0 Temperature', color='DarkBlue', label=rack+'_u0');
    us.append(u)
    for i, item in enumerate(plannings):
        #df = pd.read_csv('./transiant.csv')
        u = frame.plot.scatter(x='Time', y=rack+':Capacity Planning'+plannings[i]+' Temperature', color=color[i], label=rack+label[i],ax = us[i]);
        us.append(u)
    return us[6]

# %%
grapher(df,'O13')
us.clear()

# %%
# RACK O14
grapher(df,'O14')
us.clear()

# %%
# RACK O15

grapher(df,'O15')
us.clear()

# %%
# RACK O17

grapher(df,'O17')
us.clear()

# %%
# RACK O18

grapher(df,'O18')
us.clear()

# %%
# RACK O19

grapher(df,'O19')
us.clear()

# %%
# RACK O21

grapher(df,'O21')
us.clear()

# %%
# RACK O22

grapher(df,'O22')
us.clear()

# %%
# RACK R12

grapher(df,'R12')
us.clear()

# %%
# RACK R13

grapher(df,'R13')
us.clear()

# %%
# RACK R14

grapher(df,'R14')
us.clear()

# %%
# RACK R16

grapher(df,'R16')
us.clear()

# %%
# RACK R17

grapher(df,'R17')
us.clear()

# %%
# RACK R18

grapher(df,'R18')
us.clear()

# %%
# RACK R20

grapher(df,'R20')
us.clear()

# %%
# RACK R21

grapher(df,'R21')
us.clear()

# %%
import plotly as py
import plotly.graph_objs as go

py.offline.init_notebook_mode(connected = True)

def heatMap(dataframe,n):
    trace = go.Heatmap(z=[df['O13:Capacity Planning'+n+' Temperature'],df['O14:Capacity Planning'+n+' Temperature'], 
                      df['O15:Capacity Planning'+n+' Temperature'],df['O17:Capacity Planning'+n+' Temperature'], 
                      df['O18:Capacity Planning'+n+' Temperature'],df['O19:Capacity Planning'+n+' Temperature'],
                      df['O21:Capacity Planning'+n+' Temperature'],df['O22:Capacity Planning'+n+' Temperature'], 
                      df['R12:Capacity Planning'+n+' Temperature'],df['R13:Capacity Planning'+n+' Temperature'],
                      df['R14:Capacity Planning'+n+' Temperature'],df['R16:Capacity Planning'+n+' Temperature'],
                      df['R17:Capacity Planning'+n+' Temperature'],df['R18:Capacity Planning'+n+' Temperature'],
                      df['R20:Capacity Planning'+n+' Temperature'],df['R21:Capacity Planning'+n+' Temperature']],
                   x=df['Time'],
                   y=['O13_u0','O14_u0','O15_u0','O17_u0','O18_u0','O19_u0','O20_u0','O21_u0',
                      'R12_u0','R13_u0','R14_u0','R16_u0','R17_u0','R18_u0','R20_u0','R21_u0'])
    data=[trace]
    return data
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
# HEAT MAP FOR ALL RACKS TAKING U0 AS REFERENCE

py.offline.iplot(heatMap(df,'0'), filename='labelled-heatmap')
# Out:
# <div id="53ef8df4-41d4-4fc3-9297-a4622b46169d" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("53ef8df4-41d4-4fc3-9297-a4622b46169d", [{"type": "heatmap", "z": [[25.083999600000002, 25.5737, 26.3118, 26.8924999, 27.202100800000004, 27.317199699999996, 27.336900699999997, 27.3223, 27.300500899999996, 27.2873993, 27.2938995, 27.3283005, 27.392599100000005, 27.478599499999998, 27.575700800000003, 27.6725998, 27.7607994, 27.836000399999996, 27.896499600000006, 27.9433994, 27.978500399999994], [25.0776005, 25.372699700000002, 25.9013996, 26.3887005, 26.692100500000002, 26.828699100000005, 26.868499800000002, 26.865800899999996, 26.850799600000006, 26.8404999, 26.846900899999998, 26.878700300000002, 26.9382, 27.020399100000002, 27.117200899999997, 27.2199001, 27.3197994, 27.410400399999997, 27.4876003000
# ...

# %%
# HEAT MAP FOR ALL RACKS TAKING U42 AS REFERENCE

py.offline.iplot(heatMap(df,'42'), filename='labelled-heatmap')
# Out:
# <div id="81be5537-b983-455e-a20e-f859ab4009af" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("81be5537-b983-455e-a20e-f859ab4009af", [{"type": "heatmap", "z": [[25.0979996, 25.4531994, 25.949800500000002, 26.310300800000004, 26.488199199999997, 26.552799199999995, 26.571399699999997, 26.577999100000003, 26.585699100000003, 26.601100899999995, 26.629699699999996, 26.6753006, 26.739000300000004, 26.8192005, 26.911100399999995, 27.007600800000002, 27.1023006, 27.1898994, 27.266799900000002, 27.331899600000003, 27.3852005], [25.102300600000003, 25.2012997, 25.3847008, 25.5718002, 25.7185993, 25.8229008, 25.8955994, 25.9470997, 25.9852009, 26.0153008, 26.042600600000004, 26.072500199999997, 26.1109009, 26.163400699999997, 26.2334995, 26.319999699999997, 26.418399800000003, 26.520399100000002, 26.618600
# ...

# %%
# TRANSIENT STATE TRAIN SET

# %%
# SS TRAIN SET
